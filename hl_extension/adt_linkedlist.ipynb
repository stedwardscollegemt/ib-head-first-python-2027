# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# %% [markdown]
# ### Creating a singly linked list of numbers

# %%
head = Node(6)
second = Node(8)
head.next = second
